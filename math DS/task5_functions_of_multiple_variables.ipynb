# %% [markdown]
# # Домашнее задание "Функции нескольких переменных".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.cm as cm

# %%
x2 = sym.Symbol('x')
y2 = sym.Symbol('y')

f2 = x ** 2 * y - sym.sin(x * y) + sym.cos(x ** 2) + 6 * y
f_of_x2 = sym.diff(f2, x2) # для x
f_of_y2 = sym.diff(f2, y2) # для y
print(f_of_x2)
print(f_of_y2)
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)
# x**2 - x*cos(x*y) + 6

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вычислите градиент функции:
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# в точке $(1,2)$

# %%
x = torch.tensor(1.0, requires_grad=True)
y = torch.tensor(2.0, requires_grad=True)


f = 2 * x ** 2 * y ** 3 + 1/x + y ** 2 * x + 7

# Вычисляем градиенты по x и y
f.backward()

# Значения градиентов
gradient_x = x.grad.item()
gradient_y = y.grad.item()

print(gradient_x)
print(gradient_y)
# Out:
# 35.0
# 28.0

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Постройте трехмерный график функции
#
# $f(x)=x_2^2-x_1^2 x_2 + 2 x_1 x_2$

# %%
def f(x1, x2):
    return x2**2 - x1**2 * x2 + 2 * x1 * x2

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
Z = f(X1, X2)

surf = ax.plot_surface(X1, X2, Z, cmap = 'viridis')

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('f(X1, X2)')
ax.set_title('3D график функции')

plt.show()
